# %%
import numpy as np

X = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])

m = 0
c = 0

learning_rate = 0.01
epochs = 20

n = len(X)

for i in range(epochs):

    y_pred = m * X + c

    error = y_pred - y

    dm = (2/n) * np.sum(X * error)
    dc = (2/n) * np.sum(error)

    m = m - learning_rate * dm
    c = c - learning_rate * dc

    print("Iteration:", i + 1)
    print("m =", m)
    print("c =", c)
    print()

x_test = 6
prediction = m * x_test + c

print("Prediction for x = 6 is:", prediction)
# Out:
# Iteration: 1
# m = 0.44
# c = 0.12
#
# Iteration: 2
# m = 0.776
# c = 0.2112
#
# Iteration: 3
# m = 1.032608
# c = 0.280416
#
# Iteration: 4
# m = 1.22860928
# c = 0.3328512
#
# Iteration: 5
# m = 1.3783441663999998
# c = 0.3724776192
#
# Iteration: 6
# m = 1.4927597926399998
# c = 0.402327416832
#
# Iteration: 7
# m = 1.5802129932492799
# c = 0.42471528093696004
#
# Iteration: 8
# m = 1.6470832178782207
# c = 0.44140819572326406
#
# Iteration: 9
# m = 1.6982404182016162
# c = 0.45375503873610556
#
# Iteration: 10
# m = 1.7374022238730944
# c = 0.4627855128692865
#
# Iteration: 11
# m = 1.7674066038488565
# c = 0.4692856691795151
#
# Iteration: 12
# m = 1.7904200108513373
# c = 0.4738555595649934
#
# Iteration: 13
# m = 1.8080962748901435
# c = 0.4769532477226133
#
# Iteration: 14
# m = 1.8216978995509552
# c = 0.47892840627475247
#
# Iteration: 15
# m = 1.83218865727326
# c = 0.4800479641762001
#
# Iteration: 16
# m = 1.8403042748225709
# c = 0.48051568545628054
#
# Iteration: 17
# ...
