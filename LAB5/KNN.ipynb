# %%
import pandas as pd
import math

# %%
data = pd.read_csv("/content/KNNAlgorithmDataset.csv")

# %%
print(data.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data = data.drop(["id","Unnamed: 32"], axis=1)

# %%
data["diagnosis"] = data["diagnosis"].map({"M":1, "B":0})

# %%
dataset = data.values.tolist()

# %%
X = [row[1:] for row in dataset]
y = [row[0] for row in dataset]

# %%
test = X[0]

k = 5

distances = []

# Step 1: Find distance
for i in range(len(X)):

    d = 0
    for j in range(len(test)):
        d += (test[j] - X[i][j])**2

    d = math.sqrt(d)

    distances.append((d,y[i]))

# %%
distances.sort()

# %%
neighbors = distances[:k]

# %%
count = {0:0, 1:0}

for d,label in neighbors:
    count[label] += 1

prediction = max(count, key=count.get)

print("Prediction:", prediction)
# Out:
# Prediction: 1

# %%
import pandas as pd
import math
import random

# %%
data = pd.read_csv("/content/KNNAlgorithmDataset.csv")

# %%
print(data.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data = data.drop(["id", "Unnamed: 32"], axis=1)

# %%
data["diagnosis"] = data["diagnosis"].map({"M":1, "B":0})

# %%
dataset = data.values.tolist()


random.shuffle(dataset)


split = int(0.8 * len(dataset))
train = dataset[:split]
test = dataset[split:]

# %%
X_train = [row[1:] for row in train]
y_train = [row[0] for row in train]

X_test = [row[1:] for row in test]
y_test = [row[0] for row in test]

# %%
n = len(X_train)
k = int(math.sqrt(n))

if k % 2 == 0:
  k=k+1
print("Value of K:", k)
# Out:
# Value of K: 21

# %%
def distance(a,b):
    d = 0
    for i in range(len(a)):
        d += (a[i] - b[i])**2
    return math.sqrt(d)

# %%
def knn_predict(test_point):

    distances = []


    for i in range(len(X_train)):
        d = distance(test_point, X_train[i])
        distances.append((d, y_train[i]))


    distances.sort()


    neighbors = distances[:k]

    count = {0:0, 1:0}

    for d,label in neighbors:
        count[label] += 1

    return max(count, key=count.get)

# %%
correct = 0

for i in range(len(X_test)):
    pred = knn_predict(X_test[i])

    if pred == y_test[i]:
        correct += 1

accuracy = correct / len(X_test)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9298245614035088

# %%
import pandas as pd
import math
import random
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

data = pd.read_csv("/content/KNNAlgorithmDataset.csv")

data = data.drop(["id", "Unnamed: 32"], axis=1)

data["diagnosis"] = data["diagnosis"].map({"M":1, "B":0})

dataset = data.values.tolist()

random.shuffle(dataset)

split = int(0.8 * len(dataset))
train = dataset[:split]
test = dataset[split:]

X_train = [row[1:] for row in train]
y_train = [row[0] for row in train]

X_test = [row[1:] for row in test]
y_test = [row[0] for row in test]

best_k = 1
best_score = 0

for k in range(1, 31, 2):
    model = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')
    avg_score = scores.mean()

    print("K =", k, "Cross Validation Accuracy =", avg_score)

    if avg_score > best_score:
        best_score = avg_score
        best_k = k

k = best_k
print("Best value of K:", k)

def distance(a,b):
    d = 0
    for i in range(len(a)):
        d += (a[i] - b[i])**2
    return math.sqrt(d)

def knn_predict(test_point):

    distances = []

    for i in range(len(X_train)):
        d = distance(test_point, X_train[i])
        distances.append((d, y_train[i]))

    distances.sort()

    neighbors = distances[:k]

    count = {0:0, 1:0}

    for d,label in neighbors:
        count[label] += 1

    return max(count, key=count.get)

correct = 0

for i in range(len(X_test)):
    pred = knn_predict(X_test[i])

    if pred == y_test[i]:
        correct += 1

accuracy = correct / len(X_test)

print("Accuracy:", accuracy)
# Out:
# K = 1 Cross Validation Accuracy = 0.9032967032967033
# K = 3 Cross Validation Accuracy = 0.923076923076923
# K = 5 Cross Validation Accuracy = 0.9274725274725275
# K = 7 Cross Validation Accuracy = 0.9274725274725275
# K = 9 Cross Validation Accuracy = 0.9340659340659341
# K = 11 Cross Validation Accuracy = 0.9296703296703297
# K = 13 Cross Validation Accuracy = 0.9274725274725275
# K = 15 Cross Validation Accuracy = 0.9274725274725275
# K = 17 Cross Validation Accuracy = 0.9296703296703297
# K = 19 Cross Validation Accuracy = 0.9296703296703297
# K = 21 Cross Validation Accuracy = 0.9296703296703297
# K = 23 Cross Validation Accuracy = 0.9186813186813186
# K = 25 Cross Validation Accuracy = 0.9164835164835164
# K = 27 Cross Validation Accuracy = 0.9142857142857143
# K = 29 Cross Validation Accuracy = 0.9164835164835164
# Best value of K: 9
# Accuracy: 0.9385964912280702
